# %%
# Reproducibility setup
import os, sys, random
import numpy as np
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))
np.random.seed(42)
random.seed(42)

# %% [markdown]
# # LGD-Cashflow-and-Property-Lending - Reporting
#
# Standard notebook placeholder for the rebuilt LGD-Cashflow-and-Property-Lending workflow.

# %%
from src.demo_run_pipeline import run_pipeline
result = run_pipeline(persist=True)
result["validation"].head()
